# %%
from dotenv import load_dotenv
from browser_use import Agent, Browser, BrowserConfig
from langchain_openai import ChatOpenAI

load_dotenv()
# Out:
# INFO     [browser_use] BrowserUse logging setup complete with level info
# INFO     [telemetry] Anonymized telemetry enabled. See https://docs.browser-use.com/development/telemetry for more information.
# True

# %% [markdown]
# # WeddingWire Messenger
#
# This class provides automated tools for interacting with WeddingWire's messaging system. It allows you to search through chat histories with venues and send messages to venues directly. The class uses browser automation to handle the interactions, making it possible to programmatically manage your WeddingWire communications. Note that you'll need to be logged into WeddingWire (via cookies) to use these features.

# %% [markdown]
# # Task #1 - Send a custom message to a venue

# %%
VENUE_NAME = "Riverside Farm"
MSG = "We're still very interested in your venue for our wedding on Feb 1, 2027. Could you please send over more details about available packages and what's included?"

task_send_message = f"""
Go to weddingwire.com/users-login.php and make sure that we are logged in.
Wait for the dashboard to load.
Go to Inbox (messages).
Open the conversation with the venue named {VENUE_NAME} in the inbox.
Send the following message:
'{MSG}'
Close the browser.
"""

# %%
task_send_message
# Out:
# "\nGo to weddingwire.com/users-login.php and make sure that we are logged in.\nWait for the dashboard to load.\nGo to Inbox (messages).\nOpen the conversation with the venue named Riverside Farm in the inbox.\nSend the following message:\n'We're still very interested in your venue for our wedding on Feb 1, 2027. Could you please send over more details about available packages and what's included?'\n"

# %%
async def main():
    # Configure the browser to connect to your Chrome instance
    browser = Browser(
        config=BrowserConfig(
            browser_binary_path='/Applications/Google Chrome.app/Contents/MacOS/Google Chrome'  
        )
    )

    # Create the agent with the configured browser
    agent = Agent(
        task=task_send_message,  # Your task variable
        llm=ChatOpenAI(model="gpt-4o"),
        browser=browser
    )

    # Run the agent
    await agent.run()

    # Optional: Keep the browser open until user input
    input('Press Enter to close the browser...')
    await browser.close()

await main()
# Out:
# INFO     [agent] 🧠 Starting an agent with main_model=gpt-4o +tools +vision +memory, planner_model=None, extraction_model=gpt-4o
# INFO     [mem0.vector_stores.faiss] Loaded FAISS index from /tmp/mem0_1536_faiss/mem0.faiss with 3 vectors
# INFO     [mem0.vector_stores.faiss] Loaded FAISS index from /Users/victor/.mem0/migrations_faiss/mem0_migrations.faiss with 11 vectors
# INFO     [agent] 🚀 Starting task:
# Go to https://www.weddingwire.com/login and log in using:
# Email: victor.radermecker@gmail.com
# Password: k#@NDBF!o67rMApy
# Wait for the dashboard to load.
# Open the conversation with the venue named Riverside Farm in the inbox.
# Send the following message:
# 'We're still very interested in your venue for our wedding on Feb 1, 2027. Could you please send over more details about available packages and what's included?'
#
# INFO     [agent] 📍 Step 1
# INFO     [browser] 🔌  Reusing existing browser found running on http://localhost:9222
# INFO     [agent] 🤷 Eval: Unknown - This is the start of the task with no previous goals evaluated yet.
# INFO     [agent] 🧠 Memory: Started the task to log into WeddingWire and send a message to Riverside Farm. 0 out of 1 message sent.
# INFO     [agent] 🎯 Next goal: Open a new tab and navigate to https://www.weddingwire.com/login to start the login process.
# INFO     [agent] 🛠️  Action 1/1: {"open_tab":{"url":"https://www.weddingwire.com/login"}}
# INFO     [controller] 🔗  Opened new tab with https://www.weddingwire.com/login
# INFO     [agent] 📍 Step 2
# INFO     [agent] ⚠ Eval: Failed - The page returned a 404 error indicating it's not found.
# INFO     [agent] 🧠 Memory: The attempt to navigate to the WeddingWire login page resulted in a 404 error. 0 out of 1 message sent. Next step should be to go back to the homepage and navigate from there.
# INFO     [agent] 🎯 Next goal: Navigate back to the homepage and locate the login section from there.
# INFO     [agent] 🛠️  Action 1/1: {"click_element_by_index":{"index":14}}
# INFO     [controller] 🖱️  Clicked button with index 14: back to the homepage.
# INFO     [agent] 📍 Step 3
# INFO     [agent] ⚠ Eval: Failed - The previous attempt to find a login path directly led to a 404 error.
# INFO     [agent] 🧠 Memory: Back at WeddingWire homepage. Need to locate the login section. 0 out of 1 message sent.
# INFO     [agent] 🎯 Next goal: Look for a way to log in again. The previous login page was not accessible.
# INFO     [agent] 🛠️  Action 1/1: {"scroll_to_text":{"text":"Inbox"}}
# INFO     [controller] Text 'Inbox' not found or not visible on page
# INFO     [agent] 📍 Step 4
# INFO     [agent] 🤷 Eval: Unknown - Navigation to the homepage did not solve the login issue as the login link was not visible.
# INFO     [agent] 🧠 Memory: Back at the WeddingWire homepage and need to locate a login path again. 0 out of 1 message sent.
# INFO     [agent] 🎯 Next goal: Locate and click on 'Inbox' to see if logging in is required there or if it allows access.
# INFO     [agent] 🛠️  Action 1/1: {"click_element_by_index":{"index":13}}
# INFO     [controller] 🖱️  Clicked button with index 13:
# INFO     [agent] 📍 Step 5
# INFO     [agent] 👍 Eval: Success - Opened the conversation with Riverside Farm and ready to input a message.
# INFO     [agent] 🧠 Memory: Accessed the inbox and found Riverside Farm conversation. Ready to send the message. 0 out of 1 message sent.
# INFO     [agent] 🎯 Next goal: Enter the message text in the conversation with Riverside Farm.
# INFO     [agent] 🛠️  Action 1/1: {"input_text":{"index":32,"text":"We're still very interested in your venue for our wedding on Feb 1, 2027. Could you please send over more details about available packages and what's included?"}}
# INFO     [controller] ⌨️  Input We're still very interested in your venue for our wedding on Feb 1, 2027. Could you please send over more details about available packages and what's included? into index 32
# INFO     [agent] 📍 Step 6
# INFO     [agent] 👍 Eval: Success - The message has been successfully inputted in the conversation with Riverside Farm.
# INFO     [agent] 🧠 Memory: The message to Riverside Farm has been inputted. The next step is to send the message. 0 out of 1 message sent.
# INFO     [agent] 🎯 Next goal: Send the message in the Riverside Farm conversation.
# INFO     [agent] 🛠️  Action 1/1: {"click_element_by_index":{"index":34}}
# INFO     [controller] 🖱️  Clicked button with index 34:
# INFO     [agent] 📍 Step 7
# INFO     [agent] 👍 Eval: Success - The message to Riverside Farm was already sent successfully.
# INFO     [agent] 🧠 Memory: Messages to Riverside Farm were successfully sent. 1 out of 1 message sent.
# INFO     [agent] 🎯 Next goal: The task is complete since the message has been confirmed as sent.
# INFO     [agent] 🛠️  Action 1/1: {"done":{"text":"Successfully logged in to WeddingWire, accessed the inbox, and sent the message to Riverside Farm as requested.","success":true}}
# INFO     [agent] 📄 Result: Successfully logged in to WeddingWire, accessed the inbox, and sent the message to Riverside Farm as requested.
# INFO     [agent] ✅ Task completed
# INFO     [agent] ✅ Successfully
# INFO     [agent] 📝 Total input tokens used (approximate): 32571

# %% [markdown]
# # Retrieve the chat history

# %%
VENUE_NAME = "Riverside Farm"

task_retrieve_chat_hsty = """
Go to weddingwire.com/users-login.php and make sure that we are logged in.
Wait for the dashboard to load.
Go to Inbox (messages).
Open the conversation with the venue named {VENUE_NAME} in the inbox.
Output the chat history.
Close the browser.
"""

# %%
task_retrieve_chat_hsty
# Out:
# '\nGo to weddingwire.com/users-login.php and make sure that we are logged in.\nWait for the dashboard to load.\nGo to Inbox (messages).\nOpen the conversation with the venue named {VENUE_NAME} in the inbox.\nOutput the chat history.\nClose the browser.\n'

# %%
async def main():
    # Configure the browser to connect to your Chrome instance
    browser = Browser(
        config=BrowserConfig(
            browser_binary_path='/Applications/Google Chrome.app/Contents/MacOS/Google Chrome'  
        )
    )

    # Create the agent with the configured browser
    agent = Agent(
        task=task_retrieve_chat_hsty,  # Your task variable
        llm=ChatOpenAI(model="gpt-4o"),
        browser=browser
    )

    # Run the agent
    await agent.run()

    # Optional: Keep the browser open until user input
    input('Press Enter to close the browser...')
    await browser.close()

await main()
# Out:
# INFO     [agent] 🧠 Starting an agent with main_model=gpt-4o +tools +vision +memory, planner_model=None, extraction_model=gpt-4o
# INFO     [mem0.vector_stores.faiss] Loaded FAISS index from /tmp/mem0_1536_faiss/mem0.faiss with 3 vectors
# INFO     [mem0.vector_stores.faiss] Loaded FAISS index from /Users/victor/.mem0/migrations_faiss/mem0_migrations.faiss with 11 vectors
# INFO     [mem0.vector_stores.faiss] Inserted 1 vectors into collection mem0_migrations
# INFO     [agent] 🚀 Starting task:
# Go to weddingwire.com/users-login.php and make sure that we are logged in.
# Wait for the dashboard to load.
# Go to Inbox (messages).
# Open the conversation with the venue named {VENUE_NAME} in the inbox.
# Output the chat history.
# Close the browser.
#
# INFO     [agent] 📍 Step 1
# /Users/victor/Documents/Monica-AI/.venv/lib/python3.12/site-packages/faiss/loader.py:49: DeprecationWarning: numpy.core._multiarray_umath is deprecated and has been renamed to numpy._core._multiarray_umath. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core._multiarray_umath.__cpu_features__.
#   from numpy.core._multiarray_umath import __cpu_features__
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type swigvarlink has no __module__ attribute
# INFO     [browser] 🔌  Reusing existing browser found running on http://localhost:9222
# INFO     [agent] 🤷 Eval: Unknown - No previous actions related to the current ultimate task have been taken.
# INFO     [agent] 🧠 Memory: Starting the task fresh. Need to log in to WeddingWire and access the inbox to find and extract chat history with the specified venue.
# INFO     [agent] 🎯 Next goal: Navigate to the WeddingWire login page.
# INFO     [agent] 🛠️  Action 1/1: {"go_to_url":{"url":"https://www.weddingwire.com/users-login.php"}}
# INFO     [controller] 🔗  Navigated to https://www.weddingwire.com/users-login.php
# INFO     [agent] 📍 Step 2
# INFO     [agent] ⚠ Eval: Failed - The browser navigated to a non-login page on WeddingWire.
# INFO     [agent] 🧠 Memory: Attempted to navigate to the WeddingWire login page, but landed on the homepage instead.
# INFO     [agent] 🎯 Next goal: Search for the login option on the homepage to access the login page.
# INFO     [agent] 🛠️  Action 1/1: {"scroll_to_text":{"text":"Log in"}}
# INFO     [controller] Text 'Log in' not found or not visible on page
# INFO     [agent] 📍 Step 3
# INFO     [agent] ⚠ Eval: Failed - Previously, the login button could not be found. Now, the home page is successfully loaded with various interactive elements.
# INFO     [agent] 🧠 Memory: We're on the WeddingWire homepage. The login link was not identified but the inbox link is present.
# INFO     [agent] 🎯 Next goal: Click on the inbox icon to access messages.
# INFO     [agent] 🛠️  Action 1/1: {"click_element_by_index":{"index":13}}
# INFO     [controller] 🖱️  Clicked button with index 13:
# INFO     [agent] 📍 Step 4
# INFO     [agent] 👍 Eval: Success - Previous goals were successful. We are logged in and in the inbox, with a conversation opened.
# INFO     [agent] 🧠 Memory: Logged into WeddingWire and accessed the inbox. Opened the conversation with 'Riverside Farm'.
# INFO     [agent] 🎯 Next goal: Extract the chat history from the conversation with 'Riverside Farm' to complete the task.
# INFO     [agent] 🛠️  Action 1/1: {"extract_content":{"goal":"Extract chat history with the venue named Riverside Farm","should_strip_link_urls":true}}
# INFO     [controller] 📄  Extracted from page
# : ```json
# {
#   "extracted_chat_history": [
#     {
#       "timestamp": "05/02/2025 - 09:03pm",
#       "sender": "You",
#       "message": "Hey there! We are interested in potentially hosting our wedding at your venue. Could you send through information on your packages? Thanks!",
#       "details": {
#         "wedding_date": "02/01/2029",
#         "guests": "75-125"
#       }
#     },
#     {
#       "timestamp": "05/02/2025 - 09:53pm",
#       "sender": "You",
#       "message": "We're still very interested in your venue for our wedding on Feb 1, 2027. Could you please send over more details about available packages and what's included?"
#     },
#     {
#       "timestamp": "05/02/2025 - 10:05pm",
#       "sender": "You",
#       "message": "Yo Whats'up?"
#     },
#     {
#       "timestamp": "05/02/2025 - 10:10pm",
#       "sender": "You",
#       "message": "We're still very interested in your venue for our wedding on Feb 1, 2027. Could you please send over more details about available packages and what's included?"
#     }
#   ]
# }
# ```
#
# INFO     [agent] 📍 Step 5
# INFO     [agent] 👍 Eval: Success - Successfully extracted chat history with Riverside Farm. Ready to complete the task as per requirements.
# INFO     [agent] 🧠 Memory: Logged into WeddingWire, accessed inbox, and extracted chat history with Riverside Farm. Ready to close the browser.
# INFO     [agent] 🎯 Next goal: Close the browser now that the task has been completed.
# INFO     [agent] 🛠️  Action 1/1: {"done":{"text":"Successfully logged into WeddingWire, accessed the inbox, opened the conversation with Riverside Farm, and extracted the chat history as required.","success":true}}
# INFO     [agent] 📄 Result: Successfully logged into WeddingWire, accessed the inbox, opened the conversation with Riverside Farm, and extracted the chat history as required.
# INFO     [agent] ✅ Task completed
# INFO     [agent] ✅ Successfully
# INFO     [agent] 📝 Total input tokens used (approximate): 21143
